# %% [markdown]
# # Anomaly Corruption Benchmark
#
# Purpose: inspect realistic corruption robustness for TyreVisionX anomaly variants. Thresholds are selected on clean validation only.

# %%
import pandas as pd
df = pd.read_csv("../../reports/anomaly/corruption_benchmark.csv") if __import__("pathlib").Path("../../reports/anomaly/corruption_benchmark.csv").exists() else pd.read_csv("reports/anomaly/corruption_benchmark.csv")
df.head()

# %%
test = df[df.split == "test"]
test.pivot_table(index="corruption", columns="variant", values="recall")

# %% [markdown]
# ## Takeaway
#
# The mild noise-robust variant preserves clean recall and improves several corrupted settings, but remaining clean false negatives still point toward patch-aware/local-feature work.
