# %% [markdown]
# # High-Recall Error Review
#
# Purpose: inspect the remaining false negatives and false positives from `resnet50_knn_threshold_sweep`.
#
# Inputs: `reports/anomaly/high_recall_false_negative_review_table.csv`, `reports/anomaly/high_recall_false_positive_review_table.csv`, and contact sheets.
#
# Status: review assets are generated; human interpretation is still required.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

fn_path = Path('reports/anomaly/high_recall_false_negative_review_table.csv')
fp_path = Path('reports/anomaly/high_recall_false_positive_review_table.csv')
display(pd.read_csv(fn_path))
display(pd.read_csv(fp_path).head(20))

# %%
for path in [
    Path('reports/anomaly/high_recall_false_negative_contact_sheet.png'),
    Path('reports/anomaly/high_recall_false_positive_contact_sheet.png'),
]:
    print(path)
    if path.exists():
        display(Image(filename=str(path)))
