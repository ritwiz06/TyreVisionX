# %% [markdown]
# # Patch False-Negative Overlap Review
#
# Purpose: compare false negatives from the high-recall reference and the strongest patch-aware variant.
#
# Inputs: `reports/anomaly/patch_false_negative_overlap/`.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

base = Path('reports/anomaly/patch_false_negative_overlap')
for name in ['false_negatives_fixed_by_candidate.csv', 'false_negatives_still_missed_by_both.csv', 'false_negatives_new_in_candidate.csv']:
    path = base / name
    print(name, path.exists())
    if path.exists():
        display(pd.read_csv(path).head(20))

sheet = base / 'false_negative_overlap_contact_sheet.png'
if sheet.exists():
    display(Image(filename=str(sheet)))
