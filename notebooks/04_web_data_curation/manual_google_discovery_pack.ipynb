# %% [markdown]
# # Manual Google Discovery Pack
#
# Purpose: help the researcher browse 40 tyre-focused Google image queries manually, record approved candidate URLs, and keep every image as a review candidate rather than a label.
#
# Inputs: generated query batches and the prefilled candidate CSV.
#
# Outputs: a manually completed approved candidate CSV for the first tyre web-candidate pilot.
#
# Status: browser-ready pack only. No scraping and no automatic labeling.

# %%
import pandas as pd

queries = pd.DataFrame([{'query_id': 'manual_google_tread_01', 'group': 'tread', 'query_text': 'new tyre tread close up high resolution', 'view_type': 'tread', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=new+tyre+tread+close+up+high+resolution+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer clear groove geometry and normal tread repetition.'}, {'query_id': 'manual_google_tread_02', 'group': 'tread', 'query_text': 'clean tire tread macro product photo', 'view_type': 'tread', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=clean+tire+tread+macro+product+photo+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer clear groove geometry and normal tread repetition.'}, {'query_id': 'manual_google_tread_03', 'group': 'tread', 'query_text': 'undamaged tyre tread pattern close up', 'view_type': 'tread', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=undamaged+tyre+tread+pattern+close+up+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer clear groove geometry and normal tread repetition.'}, {'query_id': 'manual_google_tread_04', 'group': 'tread', 'query_text': 'new car tyre tread inspection lighting', 'view_type': 'tread', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=new+car+tyre+tread+inspection+lighting+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer clear groove geometry and normal tread repetition.'}, {'query_id': 'manual_google_tread_05', 'group': 'tread', 'query_text': 'premium tyre tread close up studio', 'view_type': 'tread', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=premium+tyre+tread+close+up+studio+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer clear groove geometry and normal tread repetition.'}, {'query_id': 'manual_google_tread_06', 'group': 'tread', 'query_text': 'normal tire tread grooves close up', 'view_type': 'tread', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=normal+tire+tread+grooves+close+up+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer clear groove geometry and normal tread repetition.'}, {'query_id': 'manual_google_tread_07', 'group': 'tread', 'query_text': 'unused tyre tread surface macro', 'view_type': 'tread', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=unused+tyre+tread+surface+macro+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer clear groove geometry and normal tread repetition.'}, {'query_id': 'manual_google_tread_08', 'group': 'tread', 'query_text': 'clean truck tyre tread close up', 'view_type': 'tread', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=clean+truck+tyre+tread+close+up+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer clear groove geometry and normal tread repetition.'}, {'query_id': 'manual_google_sidewall_01', 'group': 'sidewall', 'query_text': 'clean tyre sidewall close up studio', 'view_type': 'sidewall', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=clean+tyre+sidewall+close+up+studio+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer intact sidewalls, readable lettering, and no visible cracks.'}, {'query_id': 'manual_google_sidewall_02', 'group': 'sidewall', 'query_text': 'new tire sidewall product photo', 'view_type': 'sidewall', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=new+tire+sidewall+product+photo+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer intact sidewalls, readable lettering, and no visible cracks.'}, {'query_id': 'manual_google_sidewall_03', 'group': 'sidewall', 'query_text': 'undamaged tyre sidewall lettering close up', 'view_type': 'sidewall', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=undamaged+tyre+sidewall+lettering+close+up+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer intact sidewalls, readable lettering, and no visible cracks.'}, {'query_id': 'manual_google_sidewall_04', 'group': 'sidewall', 'query_text': 'clean car tyre sidewall inspection view', 'view_type': 'sidewall', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=clean+car+tyre+sidewall+inspection+view+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer intact sidewalls, readable lettering, and no visible cracks.'}, {'query_id': 'manual_google_sidewall_05', 'group': 'sidewall', 'query_text': 'black tyre sidewall macro plain background', 'view_type': 'sidewall', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=black+tyre+sidewall+macro+plain+background+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer intact sidewalls, readable lettering, and no visible cracks.'}, {'query_id': 'manual_google_sidewall_06', 'group': 'sidewall', 'query_text': 'normal tire sidewall texture close up', 'view_type': 'sidewall', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=normal+tire+sidewall+texture+close+up+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer intact sidewalls, readable lettering, and no visible cracks.'}, {'query_id': 'manual_google_sidewall_07', 'group': 'sidewall', 'query_text': 'new radial tyre sidewall close up', 'view_type': 'sidewall', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=new+radial+tyre+sidewall+close+up+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer intact sidewalls, readable lettering, and no visible cracks.'}, {'query_id': 'manual_google_sidewall_08', 'group': 'sidewall', 'query_text': 'clean truck tyre sidewall product photo', 'view_type': 'sidewall', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=clean+truck+tyre+sidewall+product+photo+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer intact sidewalls, readable lettering, and no visible cracks.'}, {'query_id': 'manual_google_mounted_tyre_01', 'group': 'mounted_tyre', 'query_text': 'new tyre mounted on wheel product photo', 'view_type': 'mounted_wheel', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=new+tyre+mounted+on+wheel+product+photo+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Useful for whole-tyre context; avoid vehicles with accidents or heavy wear.'}, {'query_id': 'manual_google_mounted_tyre_02', 'group': 'mounted_tyre', 'query_text': 'clean tire on rim studio photo', 'view_type': 'mounted_wheel', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=clean+tire+on+rim+studio+photo+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Useful for whole-tyre context; avoid vehicles with accidents or heavy wear.'}, {'query_id': 'manual_google_mounted_tyre_03', 'group': 'mounted_tyre', 'query_text': 'undamaged mounted tyre close up', 'view_type': 'mounted_wheel', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=undamaged+mounted+tyre+close+up+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Useful for whole-tyre context; avoid vehicles with accidents or heavy wear.'}, {'query_id': 'manual_google_mounted_tyre_04', 'group': 'mounted_tyre', 'query_text': 'new car wheel tyre plain background', 'view_type': 'mounted_wheel', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=new+car+wheel+tyre+plain+background+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Useful for whole-tyre context; avoid vehicles with accidents or heavy wear.'}, {'query_id': 'manual_google_mounted_tyre_05', 'group': 'mounted_tyre', 'query_text': 'clean mounted truck tire product photo', 'view_type': 'mounted_wheel', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=clean+mounted+truck+tire+product+photo+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Useful for whole-tyre context; avoid vehicles with accidents or heavy wear.'}, {'query_id': 'manual_google_mounted_tyre_06', 'group': 'mounted_tyre', 'query_text': 'new alloy wheel tyre side view', 'view_type': 'mounted_wheel', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=new+alloy+wheel+tyre+side+view+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Useful for whole-tyre context; avoid vehicles with accidents or heavy wear.'}, {'query_id': 'manual_google_mounted_tyre_07', 'group': 'mounted_tyre', 'query_text': 'normal vehicle tyre mounted close up', 'view_type': 'mounted_wheel', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=normal+vehicle+tyre+mounted+close+up+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Useful for whole-tyre context; avoid vehicles with accidents or heavy wear.'}, {'query_id': 'manual_google_mounted_tyre_08', 'group': 'mounted_tyre', 'query_text': 'clean wheel and tyre inspection photo', 'view_type': 'mounted_wheel', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=clean+wheel+and+tyre+inspection+photo+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Useful for whole-tyre context; avoid vehicles with accidents or heavy wear.'}, {'query_id': 'manual_google_inspection_like_01', 'group': 'inspection_like', 'query_text': 'tyre inspection close up normal surface', 'view_type': 'inspection', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=tyre+inspection+close+up+normal+surface+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer neutral lighting and inspection-like framing.'}, {'query_id': 'manual_google_inspection_like_02', 'group': 'inspection_like', 'query_text': 'clean tyre inspection lighting tread', 'view_type': 'inspection', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=clean+tyre+inspection+lighting+tread+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer neutral lighting and inspection-like framing.'}, {'query_id': 'manual_google_inspection_like_03', 'group': 'inspection_like', 'query_text': 'factory tyre inspection normal close up', 'view_type': 'inspection', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=factory+tyre+inspection+normal+close+up+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer neutral lighting and inspection-like framing.'}, {'query_id': 'manual_google_inspection_like_04', 'group': 'inspection_like', 'query_text': 'undamaged tire inspection view', 'view_type': 'inspection', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=undamaged+tire+inspection+view+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer neutral lighting and inspection-like framing.'}, {'query_id': 'manual_google_inspection_like_05', 'group': 'inspection_like', 'query_text': 'new tyre quality inspection photo', 'view_type': 'inspection', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=new+tyre+quality+inspection+photo+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer neutral lighting and inspection-like framing.'}, {'query_id': 'manual_google_inspection_like_06', 'group': 'inspection_like', 'query_text': 'normal tyre surface inspection close up', 'view_type': 'inspection', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=normal+tyre+surface+inspection+close+up+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer neutral lighting and inspection-like framing.'}, {'query_id': 'manual_google_inspection_like_07', 'group': 'inspection_like', 'query_text': 'clean tire close up inspection plain background', 'view_type': 'inspection', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=clean+tire+close+up+inspection+plain+background+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer neutral lighting and inspection-like framing.'}, {'query_id': 'manual_google_inspection_like_08', 'group': 'inspection_like', 'query_text': 'tyre manufacturing inspection normal tread', 'view_type': 'inspection', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=tyre+manufacturing+inspection+normal+tread+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Prefer neutral lighting and inspection-like framing.'}, {'query_id': 'manual_google_industrial_off_highway_01', 'group': 'industrial_off_highway', 'query_text': 'new off highway tyre exterior close up', 'view_type': 'exterior', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=new+off+highway+tyre+exterior+close+up+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Broader tyre variety; reject dirt, cuts, weathering, or visible wear.'}, {'query_id': 'manual_google_industrial_off_highway_02', 'group': 'industrial_off_highway', 'query_text': 'clean industrial tyre product photo', 'view_type': 'exterior', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=clean+industrial+tyre+product+photo+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Broader tyre variety; reject dirt, cuts, weathering, or visible wear.'}, {'query_id': 'manual_google_industrial_off_highway_03', 'group': 'industrial_off_highway', 'query_text': 'undamaged heavy equipment tire exterior', 'view_type': 'exterior', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=undamaged+heavy+equipment+tire+exterior+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Broader tyre variety; reject dirt, cuts, weathering, or visible wear.'}, {'query_id': 'manual_google_industrial_off_highway_04', 'group': 'industrial_off_highway', 'query_text': 'new agriculture tyre tread close up', 'view_type': 'exterior', 'priority': 1, 'google_url': 'https://www.google.com/search?tbm=isch&q=new+agriculture+tyre+tread+close+up+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Broader tyre variety; reject dirt, cuts, weathering, or visible wear.'}, {'query_id': 'manual_google_industrial_off_highway_05', 'group': 'industrial_off_highway', 'query_text': 'clean loader tire sidewall product photo', 'view_type': 'exterior', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=clean+loader+tire+sidewall+product+photo+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Broader tyre variety; reject dirt, cuts, weathering, or visible wear.'}, {'query_id': 'manual_google_industrial_off_highway_06', 'group': 'industrial_off_highway', 'query_text': 'new mining tyre exterior studio', 'view_type': 'exterior', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=new+mining+tyre+exterior+studio+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Broader tyre variety; reject dirt, cuts, weathering, or visible wear.'}, {'query_id': 'manual_google_industrial_off_highway_07', 'group': 'industrial_off_highway', 'query_text': 'normal industrial tire tread close up', 'view_type': 'exterior', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=normal+industrial+tire+tread+close+up+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Broader tyre variety; reject dirt, cuts, weathering, or visible wear.'}, {'query_id': 'manual_google_industrial_off_highway_08', 'group': 'industrial_off_highway', 'query_text': 'clean off road tyre inspection view', 'view_type': 'exterior', 'priority': 2, 'google_url': 'https://www.google.com/search?tbm=isch&q=clean+off+road+tyre+inspection+view+-%22damage%22+-%22damaged%22+-%22cracked%22+-%22crack%22+-%22puncture%22+-%22burst%22+-%22worn+out%22+-%22scrap%22+-%22used%22+-%22failure%22+-%22defect%22+-%22flat+tire%22+-%22accident%22', 'notes': 'Broader tyre variety; reject dirt, cuts, weathering, or visible wear.'}])
queries.head()

# %%
queries.groupby('group').size().rename('query_count')

# %% [markdown]
# ## How To Use
#
# 1. Open `reports/web_collection/manual_google_query_batches.md`.
# 2. Start with priority-1 tread and sidewall queries.
# 3. For each approved candidate, fill `source_url`, `page_url`, license fields if known, and `notes` in `data/external/manual_candidate_urls/approved_tyres_pilot_urls_001_prefilled.csv`.
# 4. Do not mark any row as good. Human review happens after filtering and review-pack generation.
