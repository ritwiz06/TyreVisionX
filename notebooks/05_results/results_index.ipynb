# %% [markdown]
# # Results Index
#
# Purpose: provide a central notebook index for TyreVisionX results and reports.
#
# Inputs: files under `reports/` and optional artifacts under `artifacts/`.
#
# Outputs: status tables and links/paths only.
#
# Current status: historical results are preserved; no new experiment was recomputed by the cleanup prompt.

# %%
from pathlib import Path

for path in sorted(Path("reports").glob("**/*.md")):
    print(path)

# %%
from pathlib import Path

artifact_summaries = sorted(Path("artifacts").glob("**/summary*.csv")) if Path("artifacts").exists() else []
for path in artifact_summaries:
    print(path)

# %% [markdown]
# ## Result Integrity Rule
#
# Only report metrics as current if the run was executed and the artifacts are available. Otherwise, label the result as historical reported or pending recomputation.
